# %%
# Write a program to cluster a set of points using K-means for IRIS
# dataset. Consider, K=3, clusters. Consider Euclidean distance as the
# distance measure. Randomly initialize a cluster mean as one of the data
# points. Iterate at least for 10 iterations. After iterations are over, print the
# final cluster means for each of the clusters.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import numpy as np

# %%
iris=load_iris()
feature_names=iris.feature_names
X=iris.data
df=pd.DataFrame(X,columns=feature_names)
df['index']=df.index.astype(str)

# %%
k=3
iterations=3

initialcentroids=np.random.choice(len(df),size=k,replace=False)
m1=df.iloc[initialcentroids[0]][feature_names].values.copy()
m2=df.iloc[initialcentroids[1]][feature_names].values.copy()
m3=df.iloc[initialcentroids[2]][feature_names].values.copy()

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

# load iris
iris = load_iris()
X = iris.data
cols = iris.feature_names

df = pd.DataFrame(X, columns=cols)

# random initial 3 centroids
np.random.seed(0)
idx = np.random.choice(len(df), 3, replace=False)
m1 = df.iloc[idx[0]][cols].values
m2 = df.iloc[idx[1]][cols].values
m3 = df.iloc[idx[2]][cols].values

print("Initial centroids:")
print("m1:", m1)
print("m2:", m2)
print("m3:", m3)

for i in range(10):

    pts = df[cols].values

    # distances
    df["d1"] = np.linalg.norm(pts - m1, axis=1)
    df["d2"] = np.linalg.norm(pts - m2, axis=1)
    df["d3"] = np.linalg.norm(pts - m3, axis=1)

    # assign clusters
    df["cluster"] = df[["d1","d2","d3"]].idxmin(axis=1)
    df["cluster"] = df["cluster"].map({"d1":1,"d2":2,"d3":3})

    # compute new means
    c1 = df[df.cluster==1][cols].mean().values
    c2 = df[df.cluster==2][cols].mean().values
    c3 = df[df.cluster==3][cols].mean().values

    # update only if NOT empty cluster
    if not np.isnan(c1).any():
        m1 = c1
    if not np.isnan(c2).any():
        m2 = c2
    if not np.isnan(c3).any():
        m3 = c3

    print(f"\nIteration {i+1}")
    print("m1:", m1)
    print("m2:", m2)
    print("m3:", m3)

print("\nFINAL CENTROIDS:")
print("m1:", m1)
print("m2:", m2)
print("m3:", m3)
# Out:
# Initial centroids:
# m1: [5.8 2.8 5.1 2.4]
# m2: [6.  2.2 4.  1. ]
# m3: [5.5 4.2 1.4 0.2]
#
# Iteration 1
# m1: [6.52       2.98333333 5.42       1.95166667]
# m2: [5.875  2.705  4.135  1.2625]
# m3: [5.006 3.428 1.462 0.246]
#
# Iteration 2
# m1: [6.61578947 2.99824561 5.46842105 1.96666667]
# m2: [5.79302326 2.70465116 4.16046512 1.29069767]
# m3: [5.006 3.428 1.462 0.246]
#
# Iteration 3
# m1: [6.67735849 3.00754717 5.51320755 1.97169811]
# m2: [5.79361702 2.71914894 4.2212766  1.34255319]
# m3: [5.006 3.428 1.462 0.246]
#
# Iteration 4
# m1: [6.702 3.016 5.556 1.992]
# m2: [5.822 2.728 4.256 1.36 ]
# m3: [5.006 3.428 1.462 0.246]
#
# Iteration 5
# m1: [6.76956522 3.03695652 5.6        2.00869565]
# m2: [5.82962963 2.73148148 4.31481481 1.39259259]
# m3: [5.006 3.428 1.462 0.246]
#
# Iteration 6
# m1: [6.80232558 3.04418605 5.64883721 2.03023256]
# m2: [5.85438596 2.74210526 4.34561404 1.40877193]
# m3: [5.006 3.428 1.462 0.246]
#
# Iteration 7
# m1: [6.8275 3.07   5.7    2.0625]
# m2: [5.885      2.74       4.37666667 1.41833333]
# m3: [5.006 3.428 1.462 0.246]
#
# Iteration 8
# m1: [6.85384615 3.07692308 5.71538462 2.05384615]
# m2: [5.88360656 2.74098361 4.38852459 1.43442623]
# m3: [5.006 3.428 1.462 0.246]
#
# Iteration 9
# m1: [6.85384615 3.07692308 5.71538462 2.05384615]
# m2: [5.88360656 2.74098361 4.38852459 1.43442623]
# m3: [5.006 3.428 1.462 0.246]
#
# Iteration 10
# m1: [6.85384615 3.07692308 5.71538462 2.05384615]
# m2: [5.88360656 2.74098361 4.38852459 1.43442623]
# m3: [5.006 3.428 1.462 0.246]
#
# FINAL CENTROIDS:
# m1: [6.85384615 3.07692308 5.71538462 2.05384615]
# m2: [5.88360656 2.74098361 4.38852459 1.43442623]
# m3: [5.006 3.428 1.462 0.246]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df=sns.load_dataset("iris")
print(df.columns)
cols=df.drop("species",axis=1).columns.tolist()
k=3
iter=10

index=np.random.choice(len(df),size=3,replace=False)
m1=df.iloc[index[0]][cols].values
m2=df.iloc[index[1]][cols].values
m3=df.iloc[index[2]][cols].values



for i in range(10):
    points=df[cols].values.astype(float)
    df["d1"]=np.linalg.norm(points-m1,axis=1)
    df["d2"]=np.linalg.norm(points-m2,axis=1)
    df["d3"]=np.linalg.norm(points-m3,axis=1)

    df["Cluster"]=df[["d1","d2","d3"]].idxmin(axis=1)
    df["Cluster"]=df["Cluster"].map({"d1":1,"d2":2,"d3":3})

    m1=df[df["Cluster"]==1][cols].mean().values
    m2=df[df["Cluster"]==2][cols].mean().values
    m3=df[df["Cluster"]==3][cols].mean().values

print(m1)
print(m2)
print(m3)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'numpy.float64' object has no attribute 'sqrt'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 21
#      19 for i in range(10):
#      20     points=df[cols].values.astype(float)
# ---> 21     df["d1"]=np.linalg.norm(points-m1,axis=1)
#      22     df["d2"]=np.linalg.norm(points-m2,axis=1)
#      23     df["d3"]=np.linalg.norm(points-m3,axis=1)
#
# File D:\Python\Lib\site-packages\numpy\linalg\_linalg.py:2828, in norm(x, ord, axis, keepdims)
#    2825 elif ord is None or ord == 2:
#    2826     # special case for speedup
#    2827     s = (x.conj() * x).real
# -> 2828     return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2829 # None of the str-type keywords for ord ('fro', 'nuc')
#    2830 # are valid for vectors
#    2831 elif isinstance(ord, str):
#
# TypeError: loop of ufunc does not support argument 0 of type numpy.float64 which has no callable sqrt method
