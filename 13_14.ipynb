# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Covid Vaccine Statewise.csv")
df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
df.sample(10)
# Out:
#       Updated On                                     State  \
# 3685  06/04/2021                                    Kerala
# 1701  21/01/2021  Dadra and Nagar Haveli and Daman and Diu
# 2847  16/04/2021                          Himachal Pradesh
# 7293  10/04/2021                             Uttar Pradesh
# 6423  19/03/2021                                    Sikkim
# 5359  15/03/2021                                  Nagaland
# 5175  12/04/2021                                   Mizoram
# 6427  23/03/2021                                    Sikkim
# 4866  05/08/2021                                   Manipur
# 2727  17/07/2021                                   Haryana
#
#       Total Doses Administered  Sessions   Sites   First Dose Administered  \
# 3685                 4042344.0   93940.0    713.0                3608126.0
# 1701                      78.0      10.0      7.0                     78.0
# 2847                 1241591.0   78200.0    645.0                1112736.0
# ...

# %%
#Describe the dataset
df.describe(include='all')
# Out:
#         Updated On  State  Total Doses Administered      Sessions  \
# count         7845   7845              7.621000e+03  7.621000e+03
# unique         213     37                       NaN           NaN
# top     16/01/2021  Delhi                       NaN           NaN
# freq            37    213                       NaN           NaN
# mean           NaN    NaN              9.188171e+06  4.792358e+05
# std            NaN    NaN              3.746180e+07  1.911511e+06
# min            NaN    NaN              7.000000e+00  0.000000e+00
# 25%            NaN    NaN              1.356570e+05  6.004000e+03
# 50%            NaN    NaN              8.182020e+05  4.547000e+04
# 75%            NaN    NaN              6.625243e+06  3.428690e+05
# max            NaN    NaN              5.132284e+08  3.501031e+07
#
#               Sites   First Dose Administered  Second Dose Administered  \
# count    7621.000000             7.621000e+03              7.621000e+03
# ...

# %%
df.sample(10)
# Out:
#       Updated On                                     State  \
# 7210  17/01/2021                             Uttar Pradesh
# 1818  18/05/2021  Dadra and Nagar Haveli and Daman and Diu
# 3574  16/07/2021                                 Karnataka
# 5788  20/03/2021                                Puducherry
# 1764  25/03/2021  Dadra and Nagar Haveli and Daman and Diu
# 4870  09/08/2021                                   Manipur
# 6135  02/08/2021                                    Punjab
# 7643  26/01/2021                               West Bengal
# 2120  16/08/2021                                     Delhi
# 669   18/02/2021                         Arunachal Pradesh
#
#       Total Doses Administered   Sessions   Sites   First Dose Administered  \
# 7210                    2224.0      384.0    330.0                   2224.0
# 1818                  123865.0     6000.0     43.0                  97967.0
# 3574                26851134.0  2661733.0   4137.0               21741826.0
# ...

# %%
#Number of persons state wise vaccinated for first dose in India
firstdose=df.groupby("State")["First Dose Administered"].sum().astype(int).sort_values(ascending=False)
print(firstdose)
# Out:
# State
# India                                       28262144791
# Uttar Pradesh                                2788411358
# Maharashtra                                  2784364331
# Rajasthan                                    2201044187
# Gujarat                                      2131646009
# Karnataka                                    1873329968
# Madhya Pradesh                               1796604591
# West Bengal                                  1796449989
# Bihar                                        1470502878
# Tamil Nadu                                   1288532512
# Andhra Pradesh                               1232860845
# Kerala                                       1193845072
# Odisha                                       1032633168
# Telangana                                     880320645
# Chhattisgarh                                  796002902
# Haryana                                       755798352
# Delhi                                         624339473
# ...

# %%
#Number of persons state wise vaccinated for second dose in India
seconddose=df.groupby("State")["Second Dose Administered"].sum().astype(int).sort_values(ascending=False)
print(seconddose)
# Out:
# State
# India                                       6759621451
# Maharashtra                                  712881086
# Gujarat                                      600418376
# West Bengal                                  586146880
# Uttar Pradesh                                554435112
# Rajasthan                                    491702988
# Karnataka                                    427187178
# Kerala                                       364048753
# Andhra Pradesh                               358817595
# Madhya Pradesh                               316932957
# Tamil Nadu                                   290670622
# Bihar                                        270790571
# Odisha                                       251302794
# Telangana                                    198152946
# Delhi                                        188218946
# Chhattisgarh                                 172120400
# Haryana                                      158656058
# ...

# %%
# Just for trial filling up the Nan values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7845 entries, 0 to 7844
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated On                           7845 non-null   object
#  1   State                                7845 non-null   object
#  2   Total Doses Administered             7621 non-null   float64
#  3   Sessions                             7621 non-null   float64
#  4    Sites                               7621 non-null   float64
#  5   First Dose Administered              7621 non-null   float64
#  6   Second Dose Administered             7621 non-null   float64
#  7   Male (Doses Administered)            7461 non-null   float64
#  8   Female (Doses Administered)          7461 non-null   float64
#  9   Transgender (Doses Administered)     7461 non-null   float64
#  10   Covaxin (Doses Administered)        7621 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
#Trials
#removing the NaN values
# df["Male (Doses Administered)"]=df["Male (Doses Administered)"].fillna(df["Male (Doses Administered)"].mean())
df["Male (Doses Administered)"]=df["Male (Doses Administered)"].fillna(0)
df["Male (Doses Administered)"].isna().sum()
# Out:
# np.int64(0)

# %%
#14 Use the covid_vaccine_statewise.csv dataset and perform the
# following analytics.
# A. Describe the dataset.
# B. Number of Males vaccinated
# C.. Number of females vaccinated

malevacc=df["Male(Individuals Vaccinated)"].sum()
print(malevacc.astype(int))
# Out:
# 7138698858

# %%
femalevacc=df["Female(Individuals Vaccinated)"].sum()
print(femalevacc.astype(int))
# Out:
# 6321628736

# %%
#Trial aise hi Timepass
plt.plot(df["Total Doses Administered"],df["Male(Individuals Vaccinated)"])
plt.xlabel("Total Doses")
plt.ylabel("Male Indivisuals")
plt.show()
