# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("lipstick.csv")
df
# Out:
#     Id    Age  Income  Gender       Ms Buys
# 0    1    <21    High    Male   Single   No
# 1    2    <21    High    Male  Married   No
# 2    3  21-35    High    Male   Single  Yes
# 3    4    >35  Medium    Male   Single  Yes
# 4    5    >35     Low  Female   Single  Yes
# 5    6    >35     Low  Female  Married   No
# 6    7  21-35     Low  Female  Married  Yes
# 7    8    <21  Medium    Male   Single   No
# 8    9    <21     Low  Female  Married  Yes
# 9   10    >35  Medium  Female   Single  Yes
# 10  11    <21  Medium  Female  Married  Yes
# 11  12  21-35  Medium    Male  Married  Yes
# 12  13  21-35    High  Female   Single  Yes
# 13  14    >35  Medium    Male  Married   No

# %%
le_age=LabelEncoder()
le_Income=LabelEncoder()
le_Gender=LabelEncoder()
le_Ms=LabelEncoder()
le_Buys=LabelEncoder()
df["Age"]=le_age.fit_transform(df["Age"])
df["Income"]=le_Income.fit_transform(df["Income"])
df["Gender"]=le_Gender.fit_transform(df["Gender"])
df["Ms"]=le_Ms.fit_transform(df["Ms"])
df["Buys"]=le_Buys.fit_transform(df["Buys"])

# %%
X=df[["Age","Income","Gender","Ms"]]
Y=df["Buys"]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1)
model=DecisionTreeClassifier(criterion="entropy")
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
# Question 5
test = pd.DataFrame([{
    'Age': '<21',
    'Income': 'Low',
    'Gender': 'Male',
    'Ms': 'Married'
}])

# %%
test["Age"]=le_age.fit_transform(test["Age"])
test["Income"]=le_Income.fit_transform(test["Income"])
test["Gender"]=le_Gender.fit_transform(test["Gender"])
test["Ms"]=le_Ms.fit_transform(test["Ms"])

# %%
prediction=model.predict(test)[0]
pre_label=le_Buys.inverse_transform([prediction])[0]
pre_label
# Out:
# 'Yes'

# %%
#Question 6
test1 = pd.DataFrame([{
    "Age": ">35",
    "Income": "Medium",
    "Gender": "Female",
    "Ms": "Married"
}])

# %%
test1["Age"]=le_age.fit_transform(test1["Age"])
test1["Income"]=le_Income.fit_transform(test1["Income"])
test1["Gender"]=le_Gender.fit_transform(test1["Gender"])
test1["Ms"]=le_Ms.fit_transform(test1["Ms"])

# %%
pred2=model.predict(test1)
pre2_label=le_Buys.inverse_transform([pred2])[0]
pre2_label
# Out:
# D:\Python\Lib\site-packages\sklearn\preprocessing\_label.py:151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 'Yes'

# %%
# [Age > 35, Income =Medium, Gender = Female, Marital Status = Married]
#7th Question same as 6 exact same

# %%
#[Age = 21-35, Income = Low, Gender = Male, Marital Status = Married]
#8th Question
test3=pd.DataFrame([{
    "Age":"21-35",
    "Income":"Low",
    "Gender":"Male",
    "Ms":"Married"
}])

# %%
test3["Age"]=le_age.fit_transform(test3["Age"])
test3["Income"]=le_Income.fit_transform(test3["Income"])
test3["Gender"]=le_Gender.fit_transform(test3["Gender"])
test3["Ms"]=le_Ms.fit_transform(test3["Ms"])

# %%
pred3=model.predict(test3)
pred3_label=le_Buys.inverse_transform(pred3)[0]
pred3_label
# Out:
# 'Yes'
