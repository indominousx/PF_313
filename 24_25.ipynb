# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("House Data.csv")
df.sample()
# Out:
#        Unnamed: 0 district      price  \
# 23600       23600    tuzla  925,000TL
#
#                                                  address   AdUpdateDate  \
# 23600  ['Anasayfa', 'Satılık Daire', 'İstanbul Satılı...  21 Şubat 2022
#
#       Category GrossSquareMeters  BuildingAge  NumberFloorsofBuilding  \
# 23600  Satılık            320 m2  21 Ve Üzeri                       6
#
#            UsingStatus  ...  PriceStatus RentalIncome NumberOfBalconies  \
# 23600  Kiracı Oturuyor  ...  Genel Fiyat          NaN                 2
#
#       BalconyType HallSquareMeters WCSquareMeters IsItVideoNavigable?  \
# 23600  Açık Teras              NaN            NaN                 NaN
#
#       Subscription BathroomSquareMeters BalconySquareMeters
# 23600          NaN                  NaN                 NaN
#
# [1 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25155 entries, 0 to 25154
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                25155 non-null  int64
#  1   district                  25155 non-null  object
#  2   price                     25155 non-null  object
#  3   address                   25155 non-null  object
#  4   AdUpdateDate              25155 non-null  object
#  5   Category                  25155 non-null  object
#  6   GrossSquareMeters         25155 non-null  object
#  7   BuildingAge               25155 non-null  object
#  8   NumberFloorsofBuilding    25155 non-null  int64
#  9   UsingStatus               25155 non-null  object
#  10  EligibilityForInvestment  21506 non-null  object
#  11  BuildStatus               11231 non-null  object
#  12  TitleStatus               9712 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                      0
# district                        0
# price                           0
# address                         0
# AdUpdateDate                    0
# Category                        0
# GrossSquareMeters               0
# BuildingAge                     0
# NumberFloorsofBuilding          0
# UsingStatus                     0
# EligibilityForInvestment     3649
# BuildStatus                 13924
# TitleStatus                 15443
# ItemStatus                   6823
# NumberOfBathrooms               0
# NumberOfWCs                 17026
# AdCreationDate                  0
# Type                            0
# NetSquareMeters                 0
# NumberOfRooms                   0
# FloorLocation                   0
# HeatingType                     0
# CreditEligibility               0
# InsideTheSite                   0
# StructureType               14749
# MortgageStatus              19097
# Swap                         4316
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# district                    object
# price                       object
# address                     object
# AdUpdateDate                object
# Category                    object
# GrossSquareMeters           object
# BuildingAge                 object
# NumberFloorsofBuilding       int64
# UsingStatus                 object
# EligibilityForInvestment    object
# BuildStatus                 object
# TitleStatus                 object
# ItemStatus                  object
# NumberOfBathrooms           object
# NumberOfWCs                 object
# AdCreationDate              object
# Type                        object
# NetSquareMeters             object
# NumberOfRooms               object
# FloorLocation               object
# HeatingType                 object
# CreditEligibility           object
# InsideTheSite               object
# StructureType               object
# MortgageStatus              object
# Swap                        object
# ...

# %%
#Yaha se answer Chalu.
uniquecount=df.nunique()
uniquecount
# Out:
# Unnamed: 0                  25155
# district                       39
# price                        2825
# address                      1638
# AdUpdateDate                  186
# Category                        1
# GrossSquareMeters             584
# BuildingAge                    10
# NumberFloorsofBuilding         55
# UsingStatus                     3
# EligibilityForInvestment        3
# BuildStatus                     3
# TitleStatus                     5
# ItemStatus                      2
# NumberOfBathrooms               7
# NumberOfWCs                     7
# AdCreationDate                728
# Type                            1
# NetSquareMeters               517
# NumberOfRooms                  27
# FloorLocation                  55
# HeatingType                    15
# CreditEligibility               3
# InsideTheSite                   2
# StructureType                   8
# MortgageStatus                  2
# Swap                            2
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# district                    object
# price                       object
# address                     object
# AdUpdateDate                object
# Category                    object
# GrossSquareMeters           object
# BuildingAge                 object
# NumberFloorsofBuilding       int64
# UsingStatus                 object
# EligibilityForInvestment    object
# BuildStatus                 object
# TitleStatus                 object
# ItemStatus                  object
# NumberOfBathrooms           object
# NumberOfWCs                 object
# AdCreationDate              object
# Type                        object
# NetSquareMeters             object
# NumberOfRooms               object
# FloorLocation               object
# HeatingType                 object
# CreditEligibility           object
# InsideTheSite               object
# StructureType               object
# MortgageStatus              object
# Swap                        object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25155 entries, 0 to 25154
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                25155 non-null  int64
#  1   district                  25155 non-null  object
#  2   price                     25155 non-null  object
#  3   address                   25155 non-null  object
#  4   AdUpdateDate              25155 non-null  object
#  5   Category                  25155 non-null  object
#  6   GrossSquareMeters         25155 non-null  object
#  7   BuildingAge               25155 non-null  object
#  8   NumberFloorsofBuilding    25155 non-null  int64
#  9   UsingStatus               25155 non-null  object
#  10  EligibilityForInvestment  21506 non-null  object
#  11  BuildStatus               11231 non-null  object
#  12  TitleStatus               9712 non-null   object
# ...

# %%
# df.isna().sum()
df=df.replace(["?"," ","-","None","nan"],pd.NA)
df.isna().sum()
# Out:
# Unnamed: 0                      0
# district                        0
# price                           0
# address                         0
# AdUpdateDate                    0
# Category                        0
# GrossSquareMeters               0
# BuildingAge                     0
# NumberFloorsofBuilding          0
# UsingStatus                     0
# EligibilityForInvestment     3649
# BuildStatus                 13924
# TitleStatus                 15443
# ItemStatus                   6823
# NumberOfBathrooms               0
# NumberOfWCs                 17026
# AdCreationDate                  0
# Type                            0
# NetSquareMeters                 0
# NumberOfRooms                   0
# FloorLocation                   0
# HeatingType                     0
# CreditEligibility               0
# InsideTheSite                   0
# StructureType               14749
# MortgageStatus              19097
# Swap                         4316
# ...

# %%
#convert area related columns to numbers
cols=["GrossSquareMeters", "BuildingAge", "NumberOfBathrooms", "NumberOfWCs",
    "NetSquareMeters", "NumberOfRooms", "FloorLocation",
    "RentalIncome", "NumberOfBalconies", "HallSquareMeters",
    "WCSquareMeters", "BathroomSquareMeters", "BalconySquareMeters"]
for col in cols:
    df[col]=pd.to_numeric(df[col].str.replace(r"[^0-9.]","",regex=True),errors="coerce")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 7
#       2 cols=["GrossSquareMeters", "BuildingAge", "NumberOfBathrooms", "NumberOfWCs",
#       3     "NetSquareMeters", "NumberOfRooms", "FloorLocation",
#       4     "RentalIncome", "NumberOfBalconies", "HallSquareMeters",
#       5     "WCSquareMeters", "BathroomSquareMeters", "BalconySquareMeters"]
#       6 for col in cols:
# ----> 7     df[col]=pd.to_numeric(df[col].str.replace(r"[^0-9.]","",regex=True),errors="coerce")
#       9 df["price"]=pd.to_numeric(df["price"].str.replace(r"[^0-9.]","",regex=True),errors="coerce")
#
# File D:\Python\Lib\site-packages\pandas\core\generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
# ...

# %%
df["price"]=pd.to_numeric(df["price"].str.replace(r"[^0-9.]","",regex=True),errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25155 entries, 0 to 25154
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                25155 non-null  int64
#  1   district                  25155 non-null  object
#  2   price                     25155 non-null  int64
#  3   address                   25155 non-null  object
#  4   AdUpdateDate              25155 non-null  object
#  5   Category                  25155 non-null  object
#  6   GrossSquareMeters         25155 non-null  float64
#  7   BuildingAge               25155 non-null  int64
#  8   NumberFloorsofBuilding    25155 non-null  int64
#  9   UsingStatus               25155 non-null  object
#  10  EligibilityForInvestment  21506 non-null  object
#  11  BuildStatus               11231 non-null  object
#  12  TitleStatus               9712 non-null   object
# ...

# %%
#Replace the numeircal column's NaN either with Median , Mean
df["price"]=df["price"].fillna(df["price"].mean())
df.isna().sum()
# Out:
# Unnamed: 0                      0
# district                        0
# price                           0
# address                         0
# AdUpdateDate                    0
# Category                        0
# GrossSquareMeters               0
# BuildingAge                     0
# NumberFloorsofBuilding          0
# UsingStatus                     0
# EligibilityForInvestment     3649
# BuildStatus                 13924
# TitleStatus                 15443
# ItemStatus                   6823
# NumberOfBathrooms             250
# NumberOfWCs                 17182
# AdCreationDate                  0
# Type                            0
# NetSquareMeters                 0
# NumberOfRooms                 263
# FloorLocation                7308
# HeatingType                     0
# CreditEligibility               0
# InsideTheSite                   0
# StructureType               14749
# MortgageStatus              19097
# Swap                         4316
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                    int64
# district                     object
# price                         int64
# address                      object
# AdUpdateDate                 object
# Category                     object
# GrossSquareMeters           float64
# BuildingAge                   int64
# NumberFloorsofBuilding        int64
# UsingStatus                  object
# EligibilityForInvestment     object
# BuildStatus                  object
# TitleStatus                  object
# ItemStatus                   object
# NumberOfBathrooms           float64
# NumberOfWCs                 float64
# AdCreationDate               object
# Type                         object
# NetSquareMeters             float64
# NumberOfRooms               float64
# FloorLocation               float64
# HeatingType                  object
# CreditEligibility            object
# InsideTheSite                object
# StructureType                object
# MortgageStatus               object
# ...

# %%
#Replace the Categorical Columns with Mode
catwalecol=df.select_dtypes(include="object").columns
catwalecol

for col in catwalecol:
    df[col]=df[col].fillna(df[col].mode()[0])

df.isna().sum()
# Out:
# Unnamed: 0                      0
# district                        0
# price                           0
# address                         0
# AdUpdateDate                    0
# Category                        0
# GrossSquareMeters               0
# BuildingAge                     0
# NumberFloorsofBuilding          0
# UsingStatus                     0
# EligibilityForInvestment        0
# BuildStatus                     0
# TitleStatus                     0
# ItemStatus                      0
# NumberOfBathrooms             250
# NumberOfWCs                 17182
# AdCreationDate                  0
# Type                            0
# NetSquareMeters                 0
# NumberOfRooms                 263
# FloorLocation                7308
# HeatingType                     0
# CreditEligibility               0
# InsideTheSite                   0
# StructureType                   0
# MortgageStatus                  0
# Swap                            0
# ...

# %%
#Data Transformation 
df["PricePerSqMtr"]=df["price"]/df["NetSquareMeters"]
df["PricePerSqMtr"]
# Out:
# 0        2579.034942
# 1        1596.806387
# 2        6162.558294
# 3        1758.607923
# 4        3570.408455
#             ...
# 25150    1154.806492
# 25151    3125.000000
# 25152    5136.986301
# 25153    8376.288660
# 25154    2074.688797
# Name: PricePerSqMtr, Length: 25155, dtype: float64

# %%
#Normalize Numeric Features 
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
df[["pricenorm","GrossSquareMetersNorm"]]=sc.fit_transform(df[["price","GrossSquareMeters"]])

# %%
df.to_csv("newcleaneddataset.csv",index=False)
